# %%
from chess_risk_graph import ChessRiskGraph
import networkx as nx
import chess.pgn

# %%
crg = ChessRiskGraph()
crg.board.reset()

# %%
crg.board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
crg.board.push_uci('c2c4')
# Out:
# Move.from_uci('c2c4')

# %%
crg.board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/2P5/8/PP1PPPPP/RNBQKBNR b KQkq - 0 1')

# %%
crg.board.push_uci('d7d5')
crg.board.push_uci('b2b3')
crg.board.push_uci('h7h6')
crg.board.push_uci('d2d3')
crg.board.push_uci('c8d7')
# Out:
# Move.from_uci('c8d7')

# %%
crg.board.push_uci('c1a3')
crg.board.push_uci('d7e6')
# Out:
# Move.from_uci('d7e6')

# %%
crg.board
# Out:
# Board('rn1qkbnr/ppp1ppp1/4b2p/3p4/2P5/BP1P4/P3PPPP/RN1QKBNR w KQkq - 3 5')

# %%
crg.analyze_risk()

# %%
crg.positions = nx.random_layout(crg.support_graph)
crg.draw_support_graph()

# %%
crg.draw_threat_graph()

# %%
crg.board
# Out:
# Board('rn1qkbnr/ppp1ppp1/4b2p/3p4/2P5/BP1P4/P3PPPP/RN1QKBNR w KQkq - 3 5')

# %%
crg._chess_layout()
crg.draw_support_graph()

# %%
crg.draw_support_graph()

# %%
crg.draw_threat_graph()

# %%
pgn = open("/Users/ouss/Desktop/lichess_Oussss_2020-12-25.pgn")

# %%
game = chess.pgn.read_game(pgn)

# %%
crg.board = game.board()
for move in game.mainline_moves():
    crg.board.push(move)
    crg.analyze_risk()
    crg._chess_layout()
    #crg.draw_support_graph()
    crg.draw_graph()
