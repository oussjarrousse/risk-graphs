# %%
from risk_graph_information_assurance import InformationAssuranceRiskGraph
import networkx as nx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5ff300323ec1> in <module>
# ----> 1 from risk_graph_information_assurance import InformationAssuranceRiskGraph
#       2 import networkx as nx
#
# ~/Documents/workspace/risk-graphs/risk_graph_information_assurance.py in <module>
#       1 import networkx as nx
# ----> 2 from risk_graphs import RiskGraph
#       3
#       4 class InformationAssuranceRiskGraph(RiskGraph):
#       5     def __init__(self):
#
# ~/Documents/workspace/risk-graphs/risk_graphs.py in <module>
#       1 import networkx as nx
#       2 from itertools import count
# ----> 3 import matplotlib.pyplot as plt
#       4
#       5
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
iarg = InformationAssuranceRiskGraph()
index = 0

# %%
iarg.clear_graphs()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1fa432e5be59> in <module>
# ----> 1 iarg.clear_graphs()
#
# NameError: name 'iarg' is not defined

# %%
nodes1 = [
    ( 1, {
            'index': 1,
            'label': 'Email',
            'group': 'Asset',
            'value': 10,
            'size': 10}),
    ( 2, {
            'index': 2,
            'label': 'Good\nPassword',
            'group': 'Policy',
            'value': 10,
            'size': 10,}),
]
nodes2 = [
    ( 3, {
            'index': 3,
            'label': 'Two-Factor\nAuthentication',
            'group': 'Policy',
            'value': 10,
            'size': 10}),
    ( 4, {
            'index': 4,
            'label': 'Secure\nRecovery\nMethod',
            'group': 'Policy',
            'value': 10,
            'size': 10,}),
]
nodes3 = [
    ( 5, {
            'index': 5,
            'label': 'OTP',
            'group': 'Technology',
            'value': 10,
            'size': 10,}),
]
nodes4 = [
    ( 6, {
            'index': 6,
            'label': 'freeOTP',
            'group': 'Tool',
            'value': 10,
            'size': 10,}),
    ( 7, {
            'index': 7,
            'label': 'Google\nAuthenticator',
            'group': 'Tool',
            'value': 10,
            'size': 10,}),
]

# %%
iarg.graph.add_nodes_from(nodes1)
iarg.support_graph.add_nodes_from(nodes1)
iarg.threat_graph.add_nodes_from(nodes1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5491f71b265f> in <module>
# ----> 1 iarg.graph.add_nodes_from(nodes1)
#       2 iarg.support_graph.add_nodes_from(nodes1)
#       3 iarg.threat_graph.add_nodes_from(nodes1)
#
# NameError: name 'iarg' is not defined

# %%
iarg.draw_graph()

# %%
iarg.add_support(2,1, 1)
iarg.positions = nx.random_layout(iarg.graph)
iarg.draw_support_graph()

# %%
iarg.graph.add_nodes_from(nodes2)
iarg.support_graph.add_nodes_from(nodes2)
iarg.threat_graph.add_nodes_from(nodes2)

# %%
iarg.remove_node(2)
iarg.add_support(3,1, 1)
iarg.add_support(4,1, 1)
iarg.positions = nx.spring_layout(iarg.graph)
iarg.draw_support_graph()

# %%
iarg.graph.add_nodes_from(nodes1+nodes3)
iarg.support_graph.add_nodes_from(nodes1+nodes3)
iarg.threat_graph.add_nodes_from(nodes1+nodes3)

# %%
iarg.add_support(2,3, 1)
iarg.add_support(5,3, 1)

# %%
iarg.positions = nx.spring_layout(iarg.graph)
iarg.draw_support_graph()

# %%
iarg.graph.add_nodes_from(nodes4)
iarg.support_graph.add_nodes_from(nodes4)
iarg.threat_graph.add_nodes_from(nodes4)
iarg.add_support(6,5, 1)
iarg.add_support(7,5, 1)

# %%
iarg.positions = nx.spring_layout(iarg.graph)
iarg.draw_support_graph()
